# %% [markdown]
# ## Complete Grammar

# %%
import string
import os
import json
from fractions import Fraction

def create_grammar():
    print("Creating generic grammar ")
    path = os.path.join('grammars_test','grammar1.json')

    #Setting the options
    name = "16grammar44"
    namespace = "16grammar44"
    meter_nb_beats = 4
    meter_beat_unit = 5
    levels = 4  #how many time non terminal symbols can be transformed in other non terminal
    grace_notes = 1 #maximum number of grace notes allowed
    list_of_divisions = [2,3] #list_of_division must contain only prime numbers. We can add 11, 13, etc. if we need complex tuplets
    nb_parse_fail = 0

    #create the json
    json_grammar = {
        "name": name,
        "namespace": namespace,
        "meter_nb_beats": meter_nb_beats,
        "meter_beat_unit": meter_beat_unit,
        "parse_failures_ratio": nb_parse_fail,
        "states": [],
        "rules": []

    }
    ## Create States
    # Create Terminal States
    json_grammar["states"].append({"name": "N0", "type": "cont", "nb_grace_notes":0})
    for ii in range(grace_notes + 1):
        json_grammar["states"].append(
            {"name": "N{0}".format(ii + 1), "type": "note", "nb_grace_notes": ii})
    ##Create non terminal states and rules with the recursive funcion
    first_state = {"name": (Fraction(0),Fraction(1)), "type": "non-terminal"}
    recursive_output = recursive_state_creation(first_state, list_of_divisions, 1, levels, grace_notes)
    json_grammar["states"].append(first_state)
    json_grammar["states"].extend(recursive_output[0])
    json_grammar["rules"].extend(recursive_output[1])

    # Add non-meaningful weights

    n_of_rules = len(json_grammar["rules"])
    for r in json_grammar["rules"]:
        r["weight"] = 1/n_of_rules

    return json_grammar

def recursive_state_creation(old_state, list_of_divisions, level, max_level, n_grace_notes):
    ##Create Non Terminal States
    new_states = []  # vector to temporary store states to apply recursion
    new_rules = []
    # append the rule for terminal
    for i in range(n_grace_notes + 2):
        new_rules.append({"head": old_state["name"], "body": ["N{0}".format(i)]})
    ##chose if going on or stop the recursion
    if level > max_level: #stop the recursion
        return new_states, new_rules
    else:
        for d in list_of_divisions:
            rule_body = []
            for n in range(d):
                step= (old_state["name"][1]- old_state["name"][0]) /d
                lower_bound= step* n + old_state["name"][0]
                upper_bound= step* (n+1) + old_state["name"][0]
                new_name = (lower_bound, upper_bound)
                new_states.append({"name": new_name, "type": "non-terminal"})
                ##append the rules
                # create the rule body for the old state for non-terminal
                rule_body.append(new_name)
            new_rules.append({"head": old_state["name"], "body": rule_body}) #append the body to the rule
        ##Call the recursive funcion to each element of new states
        new_new_states = new_states[:] #needed otherwise we are incrementing the list where we loop
        for s in new_states:
            recursion_output = recursive_state_creation(s, list_of_divisions, level+1, max_level, n_grace_notes)
            for s in recursion_output[0]:
                if s not in new_new_states:
                    new_new_states.append(s)
            for r in recursion_output[1]:
                if r not in new_rules:
                    new_rules.append(r)
        return  new_new_states, new_rules

# %%
grammar = create_grammar()
# Out:
# Creating generic grammar

# %%
len(grammar["states"])
# Out:
# 304

# %% [markdown]
# ## Vertical Grammar

# %%
import string
import os
import json
from fractions import Fraction

def create_vertical_grammar():
    print("Creating generic grammar ")
    path = os.path.join('grammars_test','grammar1.json')

    #Setting the options
    name = "16grammar44"
    namespace = "16grammar44"
    meter_nb_beats = 4
    meter_beat_unit = 4
    levels = 5  #how many time non terminal symbols can be transformed in other non terminal
    grace_notes = 1 #maximum number of grace notes allowed
    list_of_divisions = [2,3] #list_of_division must contain only prime numbers. We can add 11, 13, etc. if we need complex tuplets
    nb_parse_fail = 0

    #create the json
    json_grammar = {
        "name": name,
        "namespace": namespace,
        "meter_nb_beats": meter_nb_beats,
        "meter_beat_unit": meter_beat_unit,
        "parse_failures_ratio": nb_parse_fail,
        "states": [],
        "rules": []

    }
    ## Create States
    # Create Terminal States
    json_grammar["states"].append({"name": "N0", "type": "cont", "nb_grace_notes":0})
    for ii in range(grace_notes + 1):
        json_grammar["states"].append(
            {"name": "N{0}".format(ii + 1), "type": "note", "nb_grace_notes": ii})
    ##Create non terminal states and rules with the recursive funcion
    first_state = {"name": Fraction(1), "type": "non-terminal"}
    recursive_output = recursive_vertical_state_creation(first_state, list_of_divisions, 1, levels, grace_notes)
    json_grammar["states"].append(first_state)
    json_grammar["states"].extend(recursive_output[0])
    json_grammar["rules"].extend(recursive_output[1])

    # Add non-meaningful weights

    n_of_rules = len(json_grammar["rules"])
    for r in json_grammar["rules"]:
        r["weight"] = 1/n_of_rules

    return json_grammar

def recursive_vertical_state_creation(old_state, list_of_divisions, level, max_level, n_grace_notes):
    ##Create Non Terminal States
    new_states = []  # vector to temporary store states to apply recursion
    new_rules = []
    # append the rule for terminal
    for i in range(n_grace_notes + 2):
        new_rules.append({"head": old_state["name"], "body": ["N{0}".format(i)]})
    ##chose if going on or stop the recursion
    if level > max_level: #stop the recursion
        return new_states, new_rules
    else:
        for d in list_of_divisions:
            rule_body = []
            for n in range(d):
                new_name = old_state["name"] /d
                new_states.append({"name": new_name, "type": "non-terminal"})
                ##append the rules
                # create the rule body for the old state for non-terminal
                rule_body.append(new_name)
            new_rules.append({"head": old_state["name"], "body": rule_body}) #append the body to the rule
        ##Call the recursive funcion to each element of new states
        new_new_states = new_states[:] #needed otherwise we are incrementing the list where we loop
        for s in new_states:
            recursion_output = recursive_vertical_state_creation(s, list_of_divisions, level+1, max_level, n_grace_notes)
            for s in recursion_output[0]:
                if s not in new_new_states:
                    new_new_states.append(s)
            for r in recursion_output[1]:
                if r not in new_rules:
                    new_rules.append(r)
        return  new_new_states, new_rules

# %%
vert_grammar = create_vertical_grammar()
vert_grammar["rules"]
# Out:
# Creating generic grammar
# [{'body': ['N0'], 'head': Fraction(1, 1), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 1), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 1), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 2), Fraction(1, 2)],
#   'head': Fraction(1, 1),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 3), Fraction(1, 3), Fraction(1, 3)],
#   'head': Fraction(1, 1),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 2), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 2), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 2), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 4), Fraction(1, 4)],
#   'head': Fraction(1, 2),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 6), Fraction(1, 6), Fraction(1, 6)],
#   'head': Fraction(1, 2),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 4), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 4), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 4), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 8), Fraction(1, 8)],
#   'head': Fraction(1, 4),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 12), Fraction(1, 12), Fraction(1, 12)],
#   'head': Fraction(1, 4),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 8), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 8), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 8), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 16), Fraction(1, 16)],
#   'head': Fraction(1, 8),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 24), Fraction(1, 24), Fraction(1, 24)],
#   'head': Fraction(1, 8),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 16), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 16), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 16), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 32), Fraction(1, 32)],
#   'head': Fraction(1, 16),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 48), Fraction(1, 48), Fraction(1, 48)],
#   'head': Fraction(1, 16),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 32), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 32), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 32), 'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 48), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 48), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 48), 'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 24), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 24), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 24), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 48), Fraction(1, 48)],
#   'head': Fraction(1, 24),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 72), Fraction(1, 72), Fraction(1, 72)],
#   'head': Fraction(1, 24),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 72), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 72), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 72), 'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 12), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 12), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 12), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 24), Fraction(1, 24)],
#   'head': Fraction(1, 12),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 36), Fraction(1, 36), Fraction(1, 36)],
#   'head': Fraction(1, 12),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 36), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 36), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 36), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 72), Fraction(1, 72)],
#   'head': Fraction(1, 36),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 108), Fraction(1, 108), Fraction(1, 108)],
#   'head': Fraction(1, 36),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 108), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 108), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 108), 'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 6), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 6), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 6), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 12), Fraction(1, 12)],
#   'head': Fraction(1, 6),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 18), Fraction(1, 18), Fraction(1, 18)],
#   'head': Fraction(1, 6),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 18), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 18), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 18), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 36), Fraction(1, 36)],
#   'head': Fraction(1, 18),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 54), Fraction(1, 54), Fraction(1, 54)],
#   'head': Fraction(1, 18),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 54), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 54), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 54), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 108), Fraction(1, 108)],
#   'head': Fraction(1, 54),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 162), Fraction(1, 162), Fraction(1, 162)],
#   'head': Fraction(1, 54),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 162), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 162), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 162), 'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 3), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 3), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 3), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 6), Fraction(1, 6)],
#   'head': Fraction(1, 3),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 9), Fraction(1, 9), Fraction(1, 9)],
#   'head': Fraction(1, 3),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 9), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 9), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 9), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 18), Fraction(1, 18)],
#   'head': Fraction(1, 9),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 27), Fraction(1, 27), Fraction(1, 27)],
#   'head': Fraction(1, 9),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 27), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 27), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 27), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 54), Fraction(1, 54)],
#   'head': Fraction(1, 27),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 81), Fraction(1, 81), Fraction(1, 81)],
#   'head': Fraction(1, 27),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 81), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 81), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 81), 'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 162), Fraction(1, 162)],
#   'head': Fraction(1, 81),
#   'weight': 0.010752688172043012},
#  {'body': [Fraction(1, 243), Fraction(1, 243), Fraction(1, 243)],
#   'head': Fraction(1, 81),
#   'weight': 0.010752688172043012},
#  {'body': ['N0'], 'head': Fraction(1, 243), 'weight': 0.010752688172043012},
#  {'body': ['N1'], 'head': Fraction(1, 243), 'weight': 0.010752688172043012},
#  {'body': ['N2'], 'head': Fraction(1, 243), 'weight': 0.010752688172043012}]

# %%
import pickle

with open('grammars_test/json/vert_grammar1.pkl', 'wb') as outfile:  
    pickle.dump(vert_grammar, outfile)

# %% [markdown]
# ### Now print it in a file in the "qparselib" format

# %%
#to give an unique integer name to each state

class states_name_mapping:
    def __init__(self):
        self.max_int = 0
        self.mapping = {}
        
    def get_int(self, state_name):
        if state_name in self.mapping:
            return self.mapping[state_name]
        else:
            self.mapping[state_name] = self.max_int
            self.max_int +=1
            return self.mapping[state_name]
    
    def get_mapping(self):
        return self.mapping

# %%
def print_grammar(grammar, name):
    mapping = states_name_mapping()
    
    str_out = "//Grammar\n"
    str_out = "{0}{1}\n".format(str_out, "[penalty]")
    for i, r in enumerate(grammar["rules"]):
        str_out = "{0}{1}\n".format(str_out, print_rule(r,mapping))
#         print("retrieved rule " + str(i))
    str_out += "\n\n"
    #save the file
    with open(os.path.join("grammars_test",name), "w") as f:
        f.write(str_out)
    #return the grammar for later evaluation
    return mapping
            
def print_rule(rule, mapping):            
    body_str = "("
    if len(rule["body"])== 1: #if it's a terminal
        body_str = "{0} {1} ".format(body_str, rule["body"][0][1:])
    else: # if it's a non terminal
        for s in rule["body"]:
            body_str = "{0} {1} ".format(body_str, mapping.get_int(s))
    body_str = body_str + ")"
    return "{0} {1} {2}".format(mapping.get_int(rule["head"]), body_str, rule["weight"])

# %%
mapping = print_grammar(grammar)

mapping.get_mapping()
# Out:
# {(Fraction(0, 1), Fraction(1, 81)): 190,
#  (Fraction(0, 1), Fraction(1, 54)): 62,
#  (Fraction(0, 1), Fraction(1, 36)): 26,
#  (Fraction(0, 1), Fraction(1, 27)): 187,
#  (Fraction(0, 1), Fraction(1, 24)): 18,
#  (Fraction(0, 1), Fraction(1, 18)): 59,
#  (Fraction(0, 1), Fraction(1, 16)): 16,
#  (Fraction(0, 1), Fraction(1, 12)): 13,
#  (Fraction(0, 1), Fraction(1, 9)): 184,
#  (Fraction(0, 1), Fraction(1, 8)): 11,
#  (Fraction(0, 1), Fraction(1, 6)): 8,
#  (Fraction(0, 1), Fraction(1, 4)): 6,
#  (Fraction(0, 1), Fraction(1, 3)): 3,
#  (Fraction(0, 1), Fraction(1, 2)): 1,
#  (Fraction(0, 1), Fraction(1, 1)): 0,
#  (Fraction(1, 81), Fraction(2, 81)): 191,
#  (Fraction(1, 54), Fraction(1, 27)): 63,
#  (Fraction(2, 81), Fraction(1, 27)): 192,
#  (Fraction(1, 36), Fraction(1, 18)): 27,
#  (Fraction(1, 27), Fraction(4, 81)): 193,
#  (Fraction(1, 27), Fraction(1, 18)): 64,
#  (Fraction(1, 27), Fraction(2, 27)): 188,
#  (Fraction(1, 24), Fraction(1, 12)): 19,
#  (Fraction(4, 81), Fraction(5, 81)): 194,
#  (Fraction(1, 18), Fraction(2, 27)): 65,
#  (Fraction(1, 18), Fraction(1, 12)): 28,
#  (Fraction(1, 18), Fraction(1, 9)): 60,
#  (Fraction(5, 81), Fraction(2, 27)): 195,
#  (Fraction(1, 16), Fraction(1, 8)): 17,
#  (Fraction(2, 27), Fraction(7, 81)): 196,
#  (Fraction(2, 27), Fraction(5, 54)): 66,
#  (Fraction(2, 27), Fraction(1, 9)): 189,
#  (Fraction(1, 12), Fraction(1, 9)): 29,
#  (Fraction(1, 12), Fraction(1, 8)): 20,
#  (Fraction(1, 12), Fraction(1, 6)): 14,
#  (Fraction(7, 81), Fraction(8, 81)): 197,
#  (Fraction(5, 54), Fraction(1, 9)): 67,
#  (Fraction(8, 81), Fraction(1, 9)): 198,
#  (Fraction(1, 9), Fraction(10, 81)): 202,
#  (Fraction(1, 9), Fraction(7, 54)): 68,
#  (Fraction(1, 9), Fraction(5, 36)): 30,
#  (Fraction(1, 9), Fraction(4, 27)): 199,
#  (Fraction(1, 9), Fraction(1, 6)): 61,
#  (Fraction(1, 9), Fraction(2, 9)): 185,
#  (Fraction(10, 81), Fraction(11, 81)): 203,
#  (Fraction(1, 8), Fraction(1, 6)): 23,
#  (Fraction(1, 8), Fraction(3, 16)): 21,
#  (Fraction(1, 8), Fraction(1, 4)): 12,
#  (Fraction(7, 54), Fraction(4, 27)): 69,
#  (Fraction(11, 81), Fraction(4, 27)): 204,
#  (Fraction(5, 36), Fraction(1, 6)): 31,
#  (Fraction(4, 27), Fraction(13, 81)): 205,
#  (Fraction(4, 27), Fraction(1, 6)): 70,
#  (Fraction(4, 27), Fraction(5, 27)): 200,
#  (Fraction(13, 81), Fraction(14, 81)): 206,
#  (Fraction(1, 6), Fraction(5, 27)): 74,
#  (Fraction(1, 6), Fraction(7, 36)): 32,
#  (Fraction(1, 6), Fraction(5, 24)): 24,
#  (Fraction(1, 6), Fraction(2, 9)): 71,
#  (Fraction(1, 6), Fraction(1, 4)): 15,
#  (Fraction(1, 6), Fraction(1, 3)): 9,
#  (Fraction(14, 81), Fraction(5, 27)): 207,
#  (Fraction(5, 27), Fraction(16, 81)): 208,
#  (Fraction(5, 27), Fraction(11, 54)): 75,
#  (Fraction(5, 27), Fraction(2, 9)): 201,
#  (Fraction(3, 16), Fraction(1, 4)): 22,
#  (Fraction(7, 36), Fraction(2, 9)): 33,
#  (Fraction(16, 81), Fraction(17, 81)): 209,
#  (Fraction(11, 54), Fraction(2, 9)): 76,
#  (Fraction(5, 24), Fraction(1, 4)): 25,
#  (Fraction(17, 81), Fraction(2, 9)): 210,
#  (Fraction(2, 9), Fraction(19, 81)): 214,
#  (Fraction(2, 9), Fraction(13, 54)): 77,
#  (Fraction(2, 9), Fraction(1, 4)): 34,
#  (Fraction(2, 9), Fraction(7, 27)): 211,
#  (Fraction(2, 9), Fraction(5, 18)): 72,
#  (Fraction(2, 9), Fraction(1, 3)): 186,
#  (Fraction(19, 81), Fraction(20, 81)): 215,
#  (Fraction(13, 54), Fraction(7, 27)): 78,
#  (Fraction(20, 81), Fraction(7, 27)): 216,
#  (Fraction(1, 4), Fraction(5, 18)): 50,
#  (Fraction(1, 4), Fraction(7, 24)): 42,
#  (Fraction(1, 4), Fraction(5, 16)): 40,
#  (Fraction(1, 4), Fraction(1, 3)): 37,
#  (Fraction(1, 4), Fraction(3, 8)): 35,
#  (Fraction(1, 4), Fraction(1, 2)): 7,
#  (Fraction(7, 27), Fraction(22, 81)): 217,
#  (Fraction(7, 27), Fraction(5, 18)): 79,
#  (Fraction(7, 27), Fraction(8, 27)): 212,
#  (Fraction(22, 81), Fraction(23, 81)): 218,
#  (Fraction(5, 18), Fraction(8, 27)): 80,
#  (Fraction(5, 18), Fraction(11, 36)): 51,
#  (Fraction(5, 18), Fraction(1, 3)): 73,
#  (Fraction(23, 81), Fraction(8, 27)): 219,
#  (Fraction(7, 24), Fraction(1, 3)): 43,
#  (Fraction(8, 27), Fraction(25, 81)): 220,
#  (Fraction(8, 27), Fraction(17, 54)): 81,
#  (Fraction(8, 27), Fraction(1, 3)): 213,
#  (Fraction(11, 36), Fraction(1, 3)): 52,
#  (Fraction(25, 81), Fraction(26, 81)): 221,
#  (Fraction(5, 16), Fraction(3, 8)): 41,
#  (Fraction(17, 54), Fraction(1, 3)): 82,
#  (Fraction(26, 81), Fraction(1, 3)): 222,
#  (Fraction(1, 3), Fraction(28, 81)): 229,
#  (Fraction(1, 3), Fraction(19, 54)): 86,
#  (Fraction(1, 3), Fraction(13, 36)): 53,
#  (Fraction(1, 3), Fraction(10, 27)): 226,
#  (Fraction(1, 3), Fraction(3, 8)): 44,
#  (Fraction(1, 3), Fraction(7, 18)): 83,
#  (Fraction(1, 3), Fraction(5, 12)): 38,
#  (Fraction(1, 3), Fraction(4, 9)): 223,
#  (Fraction(1, 3), Fraction(1, 2)): 10,
#  (Fraction(1, 3), Fraction(2, 3)): 4,
#  (Fraction(28, 81), Fraction(29, 81)): 230,
#  (Fraction(19, 54), Fraction(10, 27)): 87,
#  (Fraction(29, 81), Fraction(10, 27)): 231,
#  (Fraction(13, 36), Fraction(7, 18)): 54,
#  (Fraction(10, 27), Fraction(31, 81)): 232,
#  (Fraction(10, 27), Fraction(7, 18)): 88,
#  (Fraction(10, 27), Fraction(11, 27)): 227,
#  (Fraction(3, 8), Fraction(5, 12)): 47,
#  (Fraction(3, 8), Fraction(7, 16)): 45,
#  (Fraction(3, 8), Fraction(1, 2)): 36,
#  (Fraction(31, 81), Fraction(32, 81)): 233,
#  (Fraction(7, 18), Fraction(11, 27)): 89,
#  (Fraction(7, 18), Fraction(5, 12)): 55,
#  (Fraction(7, 18), Fraction(4, 9)): 84,
#  (Fraction(32, 81), Fraction(11, 27)): 234,
#  (Fraction(11, 27), Fraction(34, 81)): 235,
#  (Fraction(11, 27), Fraction(23, 54)): 90,
#  (Fraction(11, 27), Fraction(4, 9)): 228,
#  (Fraction(5, 12), Fraction(4, 9)): 56,
#  (Fraction(5, 12), Fraction(11, 24)): 48,
#  (Fraction(5, 12), Fraction(1, 2)): 39,
#  (Fraction(34, 81), Fraction(35, 81)): 236,
#  (Fraction(23, 54), Fraction(4, 9)): 91,
#  (Fraction(35, 81), Fraction(4, 9)): 237,
#  (Fraction(7, 16), Fraction(1, 2)): 46,
#  (Fraction(4, 9), Fraction(37, 81)): 241,
#  (Fraction(4, 9), Fraction(25, 54)): 92,
#  (Fraction(4, 9), Fraction(17, 36)): 57,
#  (Fraction(4, 9), Fraction(13, 27)): 238,
#  (Fraction(4, 9), Fraction(1, 2)): 85,
#  (Fraction(4, 9), Fraction(5, 9)): 224,
#  (Fraction(37, 81), Fraction(38, 81)): 242,
#  (Fraction(11, 24), Fraction(1, 2)): 49,
#  (Fraction(25, 54), Fraction(13, 27)): 93,
#  (Fraction(38, 81), Fraction(13, 27)): 243,
#  (Fraction(17, 36), Fraction(1, 2)): 58,
#  (Fraction(13, 27), Fraction(40, 81)): 244,
#  (Fraction(13, 27), Fraction(1, 2)): 94,
#  (Fraction(13, 27), Fraction(14, 27)): 239,
#  (Fraction(40, 81), Fraction(41, 81)): 245,
#  (Fraction(1, 2), Fraction(14, 27)): 151,
#  (Fraction(1, 2), Fraction(19, 36)): 115,
#  (Fraction(1, 2), Fraction(13, 24)): 107,
#  (Fraction(1, 2), Fraction(5, 9)): 148,
#  (Fraction(1, 2), Fraction(9, 16)): 105,
#  (Fraction(1, 2), Fraction(7, 12)): 102,
#  (Fraction(1, 2), Fraction(5, 8)): 100,
#  (Fraction(1, 2), Fraction(2, 3)): 97,
#  (Fraction(1, 2), Fraction(3, 4)): 95,
#  (Fraction(1, 2), Fraction(1, 1)): 2,
#  (Fraction(41, 81), Fraction(14, 27)): 246,
#  (Fraction(14, 27), Fraction(43, 81)): 247,
#  (Fraction(14, 27), Fraction(29, 54)): 152,
#  (Fraction(14, 27), Fraction(5, 9)): 240,
#  (Fraction(19, 36), Fraction(5, 9)): 116,
#  (Fraction(43, 81), Fraction(44, 81)): 248,
#  (Fraction(29, 54), Fraction(5, 9)): 153,
#  (Fraction(13, 24), Fraction(7, 12)): 108,
#  (Fraction(44, 81), Fraction(5, 9)): 249,
#  (Fraction(5, 9), Fraction(46, 81)): 253,
#  (Fraction(5, 9), Fraction(31, 54)): 154,
#  (Fraction(5, 9), Fraction(7, 12)): 117,
#  (Fraction(5, 9), Fraction(16, 27)): 250,
#  (Fraction(5, 9), Fraction(11, 18)): 149,
#  (Fraction(5, 9), Fraction(2, 3)): 225,
#  (Fraction(9, 16), Fraction(5, 8)): 106,
#  (Fraction(46, 81), Fraction(47, 81)): 254,
#  (Fraction(31, 54), Fraction(16, 27)): 155,
#  (Fraction(47, 81), Fraction(16, 27)): 255,
#  (Fraction(7, 12), Fraction(11, 18)): 118,
#  (Fraction(7, 12), Fraction(5, 8)): 109,
#  (Fraction(7, 12), Fraction(2, 3)): 103,
#  (Fraction(16, 27), Fraction(49, 81)): 256,
#  (Fraction(16, 27), Fraction(11, 18)): 156,
#  (Fraction(16, 27), Fraction(17, 27)): 251,
#  (Fraction(49, 81), Fraction(50, 81)): 257,
#  (Fraction(11, 18), Fraction(17, 27)): 157,
#  (Fraction(11, 18), Fraction(23, 36)): 119,
#  (Fraction(11, 18), Fraction(2, 3)): 150,
#  (Fraction(50, 81), Fraction(17, 27)): 258,
#  (Fraction(5, 8), Fraction(2, 3)): 112,
#  (Fraction(5, 8), Fraction(11, 16)): 110,
#  (Fraction(5, 8), Fraction(3, 4)): 101,
#  (Fraction(17, 27), Fraction(52, 81)): 259,
#  (Fraction(17, 27), Fraction(35, 54)): 158,
#  (Fraction(17, 27), Fraction(2, 3)): 252,
#  (Fraction(23, 36), Fraction(2, 3)): 120,
#  (Fraction(52, 81), Fraction(53, 81)): 260,
#  (Fraction(35, 54), Fraction(2, 3)): 159,
#  (Fraction(53, 81), Fraction(2, 3)): 261,
#  (Fraction(2, 3), Fraction(55, 81)): 268,
#  (Fraction(2, 3), Fraction(37, 54)): 163,
#  (Fraction(2, 3), Fraction(25, 36)): 121,
#  (Fraction(2, 3), Fraction(19, 27)): 265,
#  (Fraction(2, 3), Fraction(17, 24)): 113,
#  (Fraction(2, 3), Fraction(13, 18)): 160,
#  (Fraction(2, 3), Fraction(3, 4)): 104,
#  (Fraction(2, 3), Fraction(7, 9)): 262,
#  (Fraction(2, 3), Fraction(5, 6)): 98,
#  (Fraction(2, 3), Fraction(1, 1)): 5,
#  (Fraction(55, 81), Fraction(56, 81)): 269,
#  (Fraction(37, 54), Fraction(19, 27)): 164,
#  (Fraction(11, 16), Fraction(3, 4)): 111,
#  (Fraction(56, 81), Fraction(19, 27)): 270,
#  (Fraction(25, 36), Fraction(13, 18)): 122,
#  (Fraction(19, 27), Fraction(58, 81)): 271,
#  (Fraction(19, 27), Fraction(13, 18)): 165,
#  (Fraction(19, 27), Fraction(20, 27)): 266,
#  (Fraction(17, 24), Fraction(3, 4)): 114,
#  (Fraction(58, 81), Fraction(59, 81)): 272,
#  (Fraction(13, 18), Fraction(20, 27)): 166,
#  (Fraction(13, 18), Fraction(3, 4)): 123,
#  (Fraction(13, 18), Fraction(7, 9)): 161,
#  (Fraction(59, 81), Fraction(20, 27)): 273,
#  (Fraction(20, 27), Fraction(61, 81)): 274,
#  (Fraction(20, 27), Fraction(41, 54)): 167,
#  (Fraction(20, 27), Fraction(7, 9)): 267,
#  (Fraction(3, 4), Fraction(7, 9)): 139,
#  (Fraction(3, 4), Fraction(19, 24)): 131,
#  (Fraction(3, 4), Fraction(13, 16)): 129,
#  (Fraction(3, 4), Fraction(5, 6)): 126,
#  (Fraction(3, 4), Fraction(7, 8)): 124,
#  (Fraction(3, 4), Fraction(1, 1)): 96,
#  (Fraction(61, 81), Fraction(62, 81)): 275,
#  (Fraction(41, 54), Fraction(7, 9)): 168,
#  (Fraction(62, 81), Fraction(7, 9)): 276,
#  (Fraction(7, 9), Fraction(64, 81)): 280,
#  (Fraction(7, 9), Fraction(43, 54)): 169,
#  (Fraction(7, 9), Fraction(29, 36)): 140,
#  (Fraction(7, 9), Fraction(22, 27)): 277,
#  (Fraction(7, 9), Fraction(5, 6)): 162,
#  (Fraction(7, 9), Fraction(8, 9)): 263,
#  (Fraction(64, 81), Fraction(65, 81)): 281,
#  (Fraction(19, 24), Fraction(5, 6)): 132,
#  (Fraction(43, 54), Fraction(22, 27)): 170,
#  (Fraction(65, 81), Fraction(22, 27)): 282,
#  (Fraction(29, 36), Fraction(5, 6)): 141,
#  (Fraction(13, 16), Fraction(7, 8)): 130,
#  (Fraction(22, 27), Fraction(67, 81)): 283,
#  (Fraction(22, 27), Fraction(5, 6)): 171,
#  (Fraction(22, 27), Fraction(23, 27)): 278,
#  (Fraction(67, 81), Fraction(68, 81)): 284,
#  (Fraction(5, 6), Fraction(23, 27)): 175,
#  (Fraction(5, 6), Fraction(31, 36)): 142,
#  (Fraction(5, 6), Fraction(7, 8)): 133,
#  (Fraction(5, 6), Fraction(8, 9)): 172,
#  (Fraction(5, 6), Fraction(11, 12)): 127,
#  (Fraction(5, 6), Fraction(1, 1)): 99,
#  (Fraction(68, 81), Fraction(23, 27)): 285,
#  (Fraction(23, 27), Fraction(70, 81)): 286,
#  (Fraction(23, 27), Fraction(47, 54)): 176,
#  (Fraction(23, 27), Fraction(8, 9)): 279,
#  (Fraction(31, 36), Fraction(8, 9)): 143,
#  (Fraction(70, 81), Fraction(71, 81)): 287,
#  (Fraction(47, 54), Fraction(8, 9)): 177,
#  (Fraction(7, 8), Fraction(11, 12)): 136,
#  (Fraction(7, 8), Fraction(15, 16)): 134,
#  (Fraction(7, 8), Fraction(1, 1)): 125,
#  (Fraction(71, 81), Fraction(8, 9)): 288,
#  (Fraction(8, 9), Fraction(73, 81)): 292,
#  (Fraction(8, 9), Fraction(49, 54)): 178,
#  (Fraction(8, 9), Fraction(11, 12)): 144,
#  (Fraction(8, 9), Fraction(25, 27)): 289,
#  (Fraction(8, 9), Fraction(17, 18)): 173,
#  (Fraction(8, 9), Fraction(1, 1)): 264,
#  (Fraction(73, 81), Fraction(74, 81)): 293,
#  (Fraction(49, 54), Fraction(25, 27)): 179,
#  (Fraction(74, 81), Fraction(25, 27)): 294,
#  (Fraction(11, 12), Fraction(17, 18)): 145,
#  (Fraction(11, 12), Fraction(23, 24)): 137,
#  (Fraction(11, 12), Fraction(1, 1)): 128,
#  (Fraction(25, 27), Fraction(76, 81)): 295,
#  (Fraction(25, 27), Fraction(17, 18)): 180,
#  (Fraction(25, 27), Fraction(26, 27)): 290,
#  (Fraction(15, 16), Fraction(1, 1)): 135,
#  (Fraction(76, 81), Fraction(77, 81)): 296,
#  (Fraction(17, 18), Fraction(26, 27)): 181,
#  (Fraction(17, 18), Fraction(35, 36)): 146,
#  (Fraction(17, 18), Fraction(1, 1)): 174,
#  (Fraction(77, 81), Fraction(26, 27)): 297,
#  (Fraction(23, 24), Fraction(1, 1)): 138,
#  (Fraction(26, 27), Fraction(79, 81)): 298,
#  (Fraction(26, 27), Fraction(53, 54)): 182,
#  (Fraction(26, 27), Fraction(1, 1)): 291,
#  (Fraction(35, 36), Fraction(1, 1)): 147,
#  (Fraction(79, 81), Fraction(80, 81)): 299,
#  (Fraction(53, 54), Fraction(1, 1)): 183,
#  (Fraction(80, 81), Fraction(1, 1)): 300}

# %%
#print the vertical grammar
mapping = print_grammar(vert_grammar,"vert_grammar1.txt")

mapping.get_mapping()
# Out:
# {Fraction(1, 243): 20,
#  Fraction(1, 162): 16,
#  Fraction(1, 108): 13,
#  Fraction(1, 81): 19,
#  Fraction(1, 72): 11,
#  Fraction(1, 54): 15,
#  Fraction(1, 48): 10,
#  Fraction(1, 36): 12,
#  Fraction(1, 32): 9,
#  Fraction(1, 27): 18,
#  Fraction(1, 24): 8,
#  Fraction(1, 18): 14,
#  Fraction(1, 16): 7,
#  Fraction(1, 12): 6,
#  Fraction(1, 9): 17,
#  Fraction(1, 8): 5,
#  Fraction(1, 6): 4,
#  Fraction(1, 4): 3,
#  Fraction(1, 3): 2,
#  Fraction(1, 2): 1,
#  Fraction(1, 1): 0}
